# %% [markdown]
# **CARBON DIOXIDE EMISSION **
#
#
# In this particular project we are going to look at the carbon dioxide emission in different sectors of the economy in different countries and regions.

# %% [markdown]
# **CASE STUDY**
#
# ---
#
#
#
# Since the 18th and 19th century there has been evoluton in the industrial sector leading to :
#
# 1. Rise of factories
# 2. Mass production
# 3. Wealth creation for countries
# 4. Urbanization
# 5. Automobile manufacturing.
# 6. Advancements in transportation
#
# -With these kind of revolution carbon dioxide emission became and is still a major disavantage of industrial revolution as there is of big mahinery that emit CO2 which is still on the rise.
#
# -CO2 emission has been on the rise with the increaaed number of indusries , machinery ,population and automobiles and also the increased deforestration in major areas of the whole world.

# %% [markdown]
# **RESEARCH QUESTIONS**
#
# 1. The industry type that had the most amount of CO2 emission in metric tonnes
#
# 2. The sector with highest amount of CO2 emission in metric tonnes.
#
# 3. Country and region with the most CO2 emission.
#
# 4. Region and country with the highest GDP in billion USD as aresult of the evolution of industries.
#
# 5. Region and country with the highest percentage of renewable energy.

# %% [markdown]
# **DATA ANALYSIS**

# %%
#IMPORTING THE DATASET
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/Co2_Emissions_by_Sectors.csv')
df.head()
# Out:
#    Industry_Type         Region       Country  Year  Co2_Emissions_MetricTons  \
# 0   Construction  North America        Brazil  2010                     89.13
# 1         Mining         Europe       Germany  2006                    224.81
# 2  Manufacturing  South America  South Africa  2017                    179.72
# 3   Construction         Europe         India  2018                     23.28
# 4   Construction         Africa         China  2013                    124.54
#
#    Energy_Consumption_TWh  Automobile_Co2_Emissions_MetricTons  \
# 0                   90.14                                98.37
# 1                  931.70                                10.81
# 2                  255.14                                55.36
# 3                  887.29                                78.99
# 4                  923.03                                65.93
#
#    Industrial_Co2_Emissions_MetricTons  Agriculture_Co2_Emissions_MetricTons  \
# ...

# %%
#GETTING A STATISTICAL SUMMARY OF THE DATASET
df.describe()
# Out:
#                Year  Co2_Emissions_MetricTons  Energy_Consumption_TWh  \
# count  17686.000000              17686.000000            17686.000000
# mean    2011.024935                150.331667              500.071501
# std        6.657483                 86.401588              287.008603
# min     2000.000000                  0.500000                0.630000
# 25%     2005.000000                 75.580000              252.447500
# 50%     2011.000000                150.820000              499.645000
# 75%     2017.000000                225.247500              750.065000
# max     2022.000000                299.990000              999.880000
#
#        Automobile_Co2_Emissions_MetricTons  \
# count                         17686.000000
# mean                             49.983267
# std                              28.936346
# min                               0.110000
# 25%                              24.712500
# 50%                              50.305000
# ...

# %%
#IDENTIFYING MSSING VALUES SO AS TO FILL THEM
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17686 entries, 0 to 17685
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Industry_Type                         17686 non-null  object
#  1   Region                                17686 non-null  object
#  2   Country                               17686 non-null  object
#  3   Year                                  17686 non-null  int64
#  4   Co2_Emissions_MetricTons              17686 non-null  float64
#  5   Energy_Consumption_TWh                17686 non-null  float64
#  6   Automobile_Co2_Emissions_MetricTons   17686 non-null  float64
#  7   Industrial_Co2_Emissions_MetricTons   17686 non-null  float64
#  8   Agriculture_Co2_Emissions_MetricTons  17686 non-null  float64
#  9   Domestic_Co2_Emissions_MetricTons     17686 non-null  float64
# ...

# %% [markdown]
# There are no null values in the dataset after the analysis.

# %%
#KNOWING THE NUMBER OF ROWS AND COLUMNS RESPECTIVELY IN THE DATASET
df.shape
# Out:
# (17686, 16)

# %%
#THE RANGE OF YEARS THAT THIS DATASET HAS FROM THE MIN TO MAX
df['Year'].min(),df['Year'].max()
# Out:
# (2000, 2022)

# %% [markdown]
# The data set has data that has been recorded for the year 2000 to 2022

# %%
df.columns
# Out:
# Index(['Industry_Type', 'Region', 'Country', 'Year',
#        'Co2_Emissions_MetricTons', 'Energy_Consumption_TWh',
#        'Automobile_Co2_Emissions_MetricTons',
#        'Industrial_Co2_Emissions_MetricTons',
#        'Agriculture_Co2_Emissions_MetricTons',
#        'Domestic_Co2_Emissions_MetricTons', 'Population_Millions',
#        'GDP_Billion_USD', 'Urbanization_Percentage',
#        'Renewable_Energy_Percentage', 'Industrial_Growth_Percentage',
#        'Transport_Growth_Percentage'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Industry_Type                            object
# Region                                   object
# Country                                  object
# Year                                      int64
# Co2_Emissions_MetricTons                float64
# Energy_Consumption_TWh                  float64
# Automobile_Co2_Emissions_MetricTons     float64
# Industrial_Co2_Emissions_MetricTons     float64
# Agriculture_Co2_Emissions_MetricTons    float64
# Domestic_Co2_Emissions_MetricTons       float64
# Population_Millions                     float64
# GDP_Billion_USD                         float64
# Urbanization_Percentage                 float64
# Renewable_Energy_Percentage             float64
# Industrial_Growth_Percentage            float64
# Transport_Growth_Percentage             float64
# dtype: object

# %%
#LOOKING FOR DUPLICATE VALUES TO AVOID OVERPRESENTATION
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  **DATA VISUALIZATION**
#
#  - From the data cleaning done there is a clear approach to the dataset as now it is well understood and visuals of it can be done for easier interpretation.
#
#  - With such a large dataset only the key mattersd are considered so as to ensure that the visuals are quite comprehensive.

# %%
#the industry_types in the dataset
df['Industry_Type'].unique()
# Out:
# array(['Construction', 'Mining', 'Manufacturing', 'Energy'], dtype=object)

# %%
#the total amount of Co2 emission in each of the sectord#the total amount of Co2 emission in each of the sector
df.groupby('Industry_Type')['Co2_Emissions_MetricTons'].sum().sort_values(ascending=False)
# Out:
# Industry_Type
# Manufacturing    681318.39
# Construction     666185.79
# Energy           658166.85
# Mining           653094.83
# Name: Co2_Emissions_MetricTons, dtype: float64

# %% [markdown]
# INDUSTRY TYPE WITH THE MOST AMOUNT OF CO2 EMISSION IN METRIC TONNES

# %%
#visualizing industry_type against Co2_Emissions_MetricTons
# Assign the result of the groupby operation to a variable called 'Co2_Emissions_MetricTons'
Co2_Emissions_MetricTons = df.groupby('Industry_Type')['Co2_Emissions_MetricTons'].sum().sort_values(ascending=False)


Co2_Emissions_MetricTons.plot(kind = 'bar')
plt.xlabel('Industry Type')
plt.ylabel('Total CO2 Emissions (Metric Tons)')
plt.title('CO2 Emissions by Industry Type')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %% [markdown]
# From the above analysis and visualization the industries types with most Co2 emissions in metric tonnes with their values respectively are:
#
# 1. Manufacturing - 681318.39
#
# 2. Construction - 666185.79
#
# 3. Energy - 658166.85
#
# 4. Mining - 653094.83

# %% [markdown]
# COUNTRY WITH THE MOST AMOUNT OF CO2 EMISSION IN METRIC TONNES

# %% [markdown]
# Getting to know the countries in the dataset.

# %%
#Getting to know the countries in the dataset

df['Country'].unique()
# Out:
# array(['Brazil', 'Germany', 'South Africa', 'India', 'China', 'Australia',
#        'Canada', 'USA'], dtype=object)

# %% [markdown]
# knowing the Co2 emission in metric tonnes for each country

# %%
#knowing the Co2 emission in metric tonnes for each country
df.groupby('Country')['Co2_Emissions_MetricTons'].sum().sort_values(ascending=False)
# Out:
# Country
# Brazil          352987.33
# Germany         336583.64
# Australia       336331.73
# Canada          331836.68
# India           330595.88
# USA             325364.63
# China           325131.99
# South Africa    319933.98
# Name: Co2_Emissions_MetricTons, dtype: float64

# %% [markdown]
# Visualizing the output so as to understand the it better

# %%
#a bar plot for the above analysis
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(11, 6))

Co2_Emissions_MetricTons = df.groupby('Country')['Co2_Emissions_MetricTons'].sum().sort_values(ascending=False)
Co2_Emissions_MetricTons.plot(kind='bar', ax=ax)

ax.set_xlabel('Country')
ax.set_ylabel('Total CO2 Emissions (Metric Tons)')
ax.set_title('CO2 Emissions by Country')
plt.xticks(rotation=45, ha='right')

#the piece of code below will highlight the exact values on top of each bar
for i, v in enumerate(Co2_Emissions_MetricTons):
    ax.text(i, v, str(v), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# COUNTRY WITH THE HIGHEST GDP IN BILLION USD.

# %% [markdown]
# - Gross domestic product(GDP) is the standard measure of the value added created through the production of goods and services in a country during a certain period.
#
# - Sorting out countries and getting their GDP and sorting them from the highest to the lowest.

# %%
#country with the highest GDP in billion USD
df.groupby('Country')['GDP_Billion_USD'].sum().sort_values(ascending=False)
# Out:
# Country
# Brazil          28945323.59
# Australia       28290751.06
# South Africa    27719295.06
# Canada          27696951.44
# Germany         27480609.15
# India           27222693.17
# USA             27079994.83
# China           27042438.47
# Name: GDP_Billion_USD, dtype: float64

# %% [markdown]
# CO2 EMISSION IN DIFFERENT REGIONS

# %%
#REGIONS WITH THE HIGHEST co2 EMISSION
df.groupby('Region')['Co2_Emissions_MetricTons'].sum().sort_values(ascending=False)
# Out:
# Region
# Oceania          452161.26
# Europe           447334.00
# South America    446798.55
# Africa           444308.58
# North America    438533.15
# Asia             429630.32
# Name: Co2_Emissions_MetricTons, dtype: float64

# %%
#representation of region against CO2 emission in metric tonnes
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(11, 6))


Co2_Emissions = df.groupby('Region')['Co2_Emissions_MetricTons'].sum().sort_values(ascending=False)


Co2_Emissions.plot(kind='bar', ax=ax)

ax.set_xlabel('Region')
ax.set_ylabel('Total CO2 Emissions (Metric Tons)')
ax.set_title('CO2 Emissions by Region')
plt.xticks(rotation=45, ha='right')

for i, v in enumerate(Co2_Emissions):
    ax.text(i, v, str(v), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# **RENEWABLE ENERGY**

# %% [markdown]
# - Renewable energy is energy from renewable natural resources that are replenished on a human timescale.
#
# - Renewable energy sources, such as wind and solar, emit little to no greenhouse gases, are readily available and in most cases cheaper than coal, oil or gas.

# %%
#getting the average percentage of renewable energy in each region
df.groupby('Region')['Renewable_Energy_Percentage'].mean().sort_values(ascending=False)
# Out:
# Region
# Oceania          50.427955
# South America    50.395685
# Africa           50.263764
# Asia             50.009069
# Europe           49.226020
# North America    49.167592
# Name: Renewable_Energy_Percentage, dtype: float64

# %% [markdown]
# INDUSTRIAL GROWTH.
#
# Industry growth is defined as the log growth rate in the sum of output across all the firms.

# %%
#a line graph showing the industrial growth in each country and the GDP in billion USD from 2000 to 2022

import matplotlib.pyplot as plt
import seaborn as sns# Create a line plot using Seaborn



filtered_df = df[(df['Year'] >= 2000) & (df['Year'] <= 2022)]


gdp_by_country_year = filtered_df.groupby(['Country', 'Year'])['GDP_Billion_USD'].sum().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x='Year', y='GDP_Billion_USD', hue='Country', data=gdp_by_country_year)

plt.title('Industrial Growth (GDP) by Country from 2000 to 2022')
plt.xlabel('Year')
plt.ylabel('GDP (Billion USD)')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Create the line plot
plt.figure(figsize=(12, 6))  # Adjust figure size for better readability
for country in grouped_df.columns:
    plt.plot(grouped_df.index, grouped_df[country], label=country)

# Customize the plot
plt.title("Industrial Growth Percentage by Country (2000-2022)")
plt.xlabel("Year")
plt.ylabel("Industrial Growth Percentage")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(True)

fig.show()
# Save the plot as a PNG image
plt.savefig("industrial_growth_plot.png")

# Display the plot (optional, but helpful for immediate feedback)
plt.show()

# %% [markdown]
# TRANSPORT GROWTH.
#
# Transportation growth refers to the establishment and prioritization of public transportation systems within urban areas to enhance mobility and accessibility.

# %%
df.groupby('Region')['Transport_Growth_Percentage'].mean().sort_values(ascending=False)
# Out:
# Region
# Africa           2.526563
# Asia             2.490719
# Europe           2.483763
# North America    2.476658
# South America    2.427462
# Oceania          2.426558
# Name: Transport_Growth_Percentage, dtype: float64

# %%
df.groupby('Country')['Transport_Growth_Percentage'].mean().sort_values(ascending=False)
# Out:
# Country
# Brazil          2.690760
# Canada          2.543051
# Germany         2.495244
# USA             2.487198
# Australia       2.418718
# South Africa    2.403912
# China           2.394998
# India           2.324176
# Name: Transport_Growth_Percentage, dtype: float64

# %% [markdown]
# **FINDINGS**
#
# ---

# %% [markdown]
# From the research and analysis done the following findings were discovered;
#
# 1) Manufacturing industry had the largest amount of CO2 emmission in metric tonnes followed by cnstruction, energy and mining industries.
#
# 2) Brazil had the highest CO2 emmission in metric tonnes followed by Germany, Canada,India, USA,China and South Africa.
#
# 3) Oceania, Europe, South America, Africa, North America and Asian regions had the highest CO2 emmissions in terms of regions respectively.
#
# 4) Brazil, Australia, SA, Canada, Germany, India, USA and China had the highest GDP in billion USD as a result of evolution of industries.
#
# 5) Oceania region had the highest percentage of renewabe energy as compared to North America which had the least.

# %% [markdown]
# RECOMMENDATIONS
#
# ---

# %% [markdown]
# 1) Transition to Renewable Energy: Given that Oceania has the highest percentage of renewable energy, other regions should prioritize transitioning to renewable energy sources like solar and wind power. This will help reduce CO2 emissions from manufacturing, construction, energy, and mining industries, which are major contributors to CO2 emissions.
#
# Reasoning: Renewable energy sources produce little to no greenhouse gases, offering a sustainable alternative to fossil fuels.
#
# 2) Sustainable Manufacturing Practices: Manufacturing industries, being the largest CO2 emitters, need to adopt sustainable practices. This includes improving energy efficiency, using recycled materials, and reducing waste.
#
# Reasoning: Implementing these practices will help minimize the environmental impact of manufacturing processes and contribute to lowering CO2 emissions.
#
# 3) Promote Public Transportation: Countries with high transport growth percentages, such as those in Oceania, should further promote and invest in public transportation systems. This can encourage a shift from private vehicles, reducing traffic congestion and CO2 emissions from transportation.
#
# Reasoning: Public transportation is generally more energy-efficient per passenger than individual vehicles, thus reducing the overall carbon footprint.
#
# 4) Sustainable Construction: Construction industries should explore and adopt sustainable building materials and techniques. This includes using eco-friendly materials, optimizing building designs for energy efficiency, and minimizing construction waste.
#
# Reasoning: Sustainable construction practices can significantly reduce the environmental impact of buildings, which are major consumers of energy and resources.
#
# 5) Carbon Capture and Storage: Research and development into carbon capture and storage technologies should be encouraged and supported. This can help mitigate CO2 emissions from industrial processes by capturing and storing CO2 emissions before they are released into the atmosphere.
#
# Reasoning: Carbon capture and storage can play a crucial role in reducing emissions from industries that are difficult to decarbonize, such as cement production.
#
# 6) International Collaboration: Countries and regions should collaborate on sharing best practices, technologies, and policies related to CO2 emissions reduction. This can accelerate the global transition to a low-carbon economy.
#
#
# ---

# %% [markdown]
# **THANK YOU**

# %% [markdown]
# **THE END**
